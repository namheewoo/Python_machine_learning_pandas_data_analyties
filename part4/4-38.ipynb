# %%
import pandas as pd
import folium

df = pd.read_excel('./data/서울지역_대학교_위치.xlsx', index_col=0)

seoul_map = folium.Map(location=[37.55,126.98], tiles="Cartodb Positron", 
                       zoom_start=12)

for name, lat, lng in zip(df.index, df['위도'], df['경도']):
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2c25756b4647ecc60f24f598ec8ba9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2c25756b4647ecc60f24f598ec8ba9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2c25756b4647ecc60f24f598ec8ba9f = L.map(
#                 &quot;map_c2c25756b4647ecc60f24f598ec8ba9f&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f46efa99c3d64d0e48ce6f239f9f075 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f46efa99c3d64d0e48ce6f239f9f075.addTo(map_c2c25756b4647ecc60f24f598ec8ba9f);
#
#
#             var marker_0d1ab00e28ddfde3dac867e0e2dc4b87 = L.marker(
#                 [37.592573, 127.046737],
#                 {
# }
#             ).addTo(map_c2c25756b4647ecc60f24f598ec8ba9f);
#
#
#         var popup_3c9b1c790d3c328c553b09d3c525a2d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb75911e8e7bec2a9becd750febf5f7a = $(`&lt;div id=&quot;html_cb75911e8e7bec2a9becd750febf5f7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_3c9b1c790d3c328c553b09d3c525a2d0.setContent(html_cb75911e8e7bec2a9becd750febf5f7a);
#
#
#
#         marker_0d1ab00e28ddfde3dac867e0e2dc4b87.bindPopup(popup_3c9b1c790d3c328c553b09d3c525a2d0)
#         ;
#
#
#
#
#             var marker_c92a215b710f2c2b9d8ebd5e1a1e9615 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {
# }
#             ).addTo(map_c2c25756b4647ecc60f24f598ec8ba9f);
#
#
#         var popup_600176f64fad21ee8e310465a271bd7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dfb144d3e8dc501d2b41c9bb0d75ec2 = $(`&lt;div id=&quot;html_0dfb144d3e8dc501d2b41c9bb0d75ec2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_600176f64fad21ee8e310465a271bd7e.setContent(html_0dfb144d3e8dc501d2b41c9bb0d75ec2);
#
#
#
#         marker_c92a215b710f2c2b9d8ebd5e1a1e9615.bindPopup(popup_600176f64fad21ee8e310465a271bd7e)
#         ;
#
#
#
#
#             var marker_3d40ec4704d21735816100212780490b = L.marker(
#                 [37.5859218, 127.0043275],
#                 {
# }
#             ).addTo(map_c2c25756b4647ecc60f24f598ec8ba9f);
#
#
#         var popup_6a24eb2d9385bcd1a3e9ea1a8147f509 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d83c590ffc0c3ff5ae69508920d5a1e = $(`&lt;div id=&quot;html_1d83c590ffc0c3ff5ae69508920d5a1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_6a24eb2d9385bcd1a3e9ea1a8147f509.setContent(html_1d83c590ffc0c3ff5ae69508920d5a1e);
#
#
#
#         marker_3d40ec4704d21735816100212780490b.bindPopup(popup_6a24eb2d9385bcd1a3e9ea1a8147f509)
#         ;
#
#
#
#
#             var marker_08ea9286d39b517e11c889e6db788363 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {
# }
#             ).addTo(map_c2c25756b4647ecc60f24f598ec8ba9f);
#
#
#         var popup_62407a23c5cd728efc065e386f30c8c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e074e201df1749b7c10c9960d236ce12 = $(`&lt;div id=&quot;html_e074e201df1749b7c10c9960d236ce12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_62407a23c5cd728efc065e386f30c8c2.setContent(html_e074e201df1749b7c10c9960d236ce12);
#
#
#
#         marker_08ea9286d39b517e11c889e6db788363.bindPopup(popup_62407a23c5cd728efc065e386f30c8c2)
#         ;
#
#
#
#
#             var marker_25b095ee6db570f5da6fa716ff616a3b = L.marker(
#                 [37.5676455, 126.96161],
#                 {
# }
#             ).addTo(map_c2c25756b4647ecc60f24f598ec8ba9f);
#
#
#         var popup_144dffd6794f1e3d096ca8ddb7715038 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6edad03188f6f64b30fd5a735effb29f = $(`&lt;div id=&quot;html_6edad03188f6f64b30fd5a735effb29f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_144dffd6794f1e3d096ca8d
